# %% [markdown]
# questions:
# -error/convergence of sum of chi squared

# %% [markdown]
# conduction of the exercises and to the meaning of the results obtained

# %% [markdown]
# ## <span style="color:red"> Exercise 01.1: test the Pseudo-Random Number generator </span>

# %% [markdown]
# ### Exercise 01.11
# Using the uniform Pseudo-Random Number generator (prng) following the RANdom New York University (RANNYU) routine implemented by Kalos and Panoff, we estimate the average of the uniform variate $r$
# $$\langle r \rangle = \int_0^1 r dr $$
# with $10^6$ extractions. The variance is estimated via the blocking method implemented with $10^2$ blocks, and results are plotted with a fixed block size and increasing block numbers. This way, we can observe the average converging towards the exact value $\frac{1}{2}$ and the uncertainty decreasing as $\sqrt{n}$

# %%
#import essential libraries
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
#parameter to use Latex in matplotlib
matplotlib.rcParams.update(matplotlib.rcParamsDefault)

# %%
#import data formatted as table from a .txt file
data = np.loadtxt('ex01.11.txt', skiprows=1)
M=1e6                 # Total number of throws
N=100                 # Number of blocks
L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
#populate and rescale x axis
x= np.arange(N)*L 
#plot the results with errors
plt.errorbar(x,data[:,0]-0.5,yerr=data[:,1], color="red", ecolor="orange")
plt.xlabel('#throws')
plt.ylabel(r"$\langle r \rangle -\frac{1}{2}$")
plt.grid(True)
plt.axhline(y=0., color= "black",linestyle='-')
plt.show()

# %% [markdown]
# Since the obtained result in compatible between $2\sigma$ (as a rough estimate) with the expected value, we are satisfied.

# %% [markdown]
# ### Exercise 01.12
# Using our prng and with the same technique, we now evaluate $\sigma^2$ for the uniform distribution $r$. the expected result is
# $$\sigma^2 = \int_0^1 (r-1/2)^2 dr = 1/12$$

# %%
#import data formatted as table from a .txt file
data = np.loadtxt('ex01.12.txt', skiprows=1)
M=1e6                 # Total number of throws
N=100                 # Number of blocks
L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
#populate and rescale x axis
x= np.arange(N)*L 
plt.errorbar(x,data[:,0]-1/12,yerr=data[:,1],color="red", ecolor="orange")
plt.xlabel('#throws')
plt.ylabel(r"$\langle(r-\langle r \rangle)^2\rangle-\frac{1}{12}$")
plt.grid(True)
plt.axhline(y=0., color= "black",linestyle='-')
plt.show()

# %% [markdown]
# With $1e6$ realizations, convergence is reached between $2\sigma$. This is an acceptable result.

# %% [markdown]
# ### Exercise 01.13
# We now check whether Pearson's cumulative test statistic $\chi^2$ rejects the hypothesis: "the data is sampled from an uniform distribution".

# %%
#import data formatted as table from a .txt file
data = np.loadtxt('ex01.13.txt', skiprows=1)
Nrealizations=1e4           # Number of extractions per chi-squared evaluation
Nevaluations=100            # Number of evaluations
#plot the chi-squared for the sampled realizations
x= np.arange(Nevaluations)
plt.scatter(x,data,color="green", s=3.5)
plt.xlabel('sample')
plt.ylabel(r"$\chi^2$")
plt.grid(True)
#evaluate and plot chi-squared mean
chiMean=np.mean(data)
chiStd=np.std(data, ddof=1)/np.sqrt(Nevaluations-1)
plt.axhline(y=chiMean, color="black")
plt.fill_between(x,chiMean-chiStd,chiMean+chiStd, color="black",alpha=0.2) #???
print(chiMean)
plt.show()
# Out:
# 98.9702

# %% [markdown]
# errore e fill between
# confronto con istogramma di chi2 con k=100

# %%
n, bins, patches = plt.hist(data,color="olivedrab", bins=10, density=True)

plt.xlabel('#throws')
plt.ylabel(r"$\langle(r-1/2)^2\rangle-\frac{1}{12}$")

from scipy.optimize import curve_fit

# Define the chi-squared function
def chiSquared(x, amplitude, k):
    return amplitude * np.exp(-x/2) * x**(k/2-1)

# Calculate the center of each bin
bin_centers = (bins[1:] + bins[:-1]) / 2

# Fit the histogram to the chi-squared function
popt, pcov = curve_fit(chiSquared, bin_centers, n)

# Plot the fitted chi-squared curve
plt.plot(bin_centers, chiSquared(bin_centers, *popt), color='black')
plt.show()
# Out:
# /home/lorenzo/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_72943/443309093.py in <module>
#      17
#      18 # Plot the fitted chi-squared curve
# ---> 19 plt.plot(bin_centers, gaussian(bin_centers, *popt), color='black')
#      20 plt.show()
#
# NameError: name 'gaussian' is not defined

# %% [markdown]
# ## <span style="color:red"> Exercise 01.2: Central Limit Theorem </span>

# %%
data = np.loadtxt('ex01.21.txt', skiprows=1)
realizations=100
x= np.arange(Nbins)
    
# Define the width of the columns
width = 1.

for i in range(4):
# Plot the data as column scatter plot
    n, bins, patches = plt.hist(data[:,i],alpha=0.5, bins=50, density=True)

plt.xlabel('#throws')
plt.ylabel(r"$\langle(r-1/2)^2\rangle-\frac{1}{12}$")

from scipy.optimize import curve_fit


# Define the Gaussian function
def gaussian(x, amplitude, mean, stddev):
    return amplitude * np.exp(-((x - mean) / stddev) ** 2)

# Calculate the center of each bin
bin_centers = (bins[1:] + bins[:-1]) / 2

# Fit the histogram to the Gaussian function
popt, pcov = curve_fit(gaussian, bin_centers, n)

# Plot the fitted Gaussian curve
plt.plot(bin_centers, gaussian(bin_centers, *popt), color='black')
plt.show()

# %%
data = np.loadtxt('ex01.22.txt', skiprows=1)
realizations=100
x= np.arange(Nbins)
    
# Define the width of the columns
width = 1.

for i in range(4):
# Plot the data as column scatter plot
    n, bins, patches = plt.hist(data[:,i],alpha=0.5, bins=50, density=True)

# Define the Gaussian function
def gaussian(x, amplitude, mean, stddev):
    return amplitude * np.exp(-((x - mean) / stddev) ** 2)

# Calculate the center of each bin
bin_centers = (bins[1:] + bins[:-1]) / 2

# Fit the histogram to the Gaussian function
popt, pcov = curve_fit(gaussian, bin_centers, n)

# Plot the fitted Gaussian curve
plt.plot(bin_centers, gaussian(bin_centers, *popt), color='black')

plt.xlabel('#throws')
plt.ylabel(r"$\langle(r-1/2)^2\rangle-\frac{1}{12}$")

print(popt)
plt.show()
# Out:
# [ 4.0412304   0.99442096 -0.13953192]

# %%
data = np.loadtxt('ex01.23.txt', skiprows=1)
realizations=100
x= np.arange(Nbins)
    
# Define the width of the columns
width = 1.
plt.xlim(xmin=-10, xmax = 10)

colors = ['red', 'yellow', 'lime','cyan']
for i in range(4):
# Plot the data as column scatter plot
    n, bins, patches = plt.hist(data[:,i],alpha=0.4, bins=80, density=True, range=[-10, 10], color = colors[i])
    
# Define the Cauchy-Lorentz function
def lorentzian(x, amplitude, gamma, mu):
    return amplitude * gamma/(gamma**2+(x-mu)**2)

# Calculate the center of each bin
bin_centers = (bins[1:] + bins[:-1]) / 2

# Fit the histogram to the Gaussian function
popt, pcov = curve_fit(lorentzian, bin_centers, n)

# Plot the fitted Gaussian curve
plt.plot(bin_centers, lorentzian(bin_centers, *popt), color='black')


plt.xlabel('#throws')
plt.ylabel(r"$\langle(r-1/2)^2\rangle-\frac{1}{12}$")

print(popt)
plt.show()
# Out:
# [ 0.34147393  1.00918612 -0.00264694]

# %% [markdown]
# The **_curve_fit_** function from the scipy.optimize module in Python uses a non-linear least-squares optimization algorithm to fit a user-defined function to data. Specifically, it uses the Levenberg-Marquardt algorithm, which is a widely used optimization algorithm for solving non-linear least-squares problems.
#
# The Levenberg-Marquardt algorithm combines the features of both the gradient descent method and the Gauss-Newton method. It starts with an initial guess for the optimal parameters and iteratively adjusts the parameters to minimize the sum of the squared residuals between the data and the user-defined function.
#
# The Levenberg-Marquardt algorithm is a robust and efficient method for curve fitting, and is commonly used in scientific and engineering applications. However, it is not guaranteed to converge to the global minimum, and may get stuck in local minima if the initial guess is poor or the function is highly non-linear or non-convex. Therefore, it is often a good idea to try different initial guesses or optimization algorithms if the results are not satisfactory.

# %% [markdown]
# ## <span style="color:red"> Exercise 01.3: Buffon Experiment: Estimation of $\pi$ </span>

# %%
data = np.loadtxt('ex01.31.txt', skiprows=1)

M=1e20             # Total number of throws
N=1e2                 # Number of blocks
L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
x= np.arange(N)*L 
plt.errorbar(x,data[:,0],yerr=data[:,1])

plt.axhline(y = np.pi, color = 'r', linestyle = '-')
plt.xlabel('#throws')
plt.ylabel(r"$\langle r \rangle -\frac{1}{2}$")
plt.grid(True)
plt.show()
